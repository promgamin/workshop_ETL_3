# %% [markdown]
# ## Importar librerias necesarias

# %%
from ydata_profiling import ProfileReport
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
plt.style.use("seaborn-v0_8")

# %% [markdown]
# ## Cargar archivos CSV

# %%
# Cargar datos del 2015
df2015 = pd.read_csv("../../datos/crudos/2015.csv", 
                   encoding="latin-1", low_memory=False)

print(f"Fuente 2015: {df2015.shape[0]} rows, {df2015.shape[1]} columns")
# Out:
# Fuente 2015: 158 rows, 12 columns

# %%
df2015.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
# Cargar datos del 2016
df2016 = pd.read_csv("../../datos/crudos/2016.csv", 
                   encoding="latin-1", low_memory=False)

print(f"Fuente 2016 (Santander): {df2016.shape[0]} rows, {df2016.shape[1]} columns")
# Out:
# Fuente 2016 (Santander): 157 rows, 13 columns

# %%
df2016.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463

# %%
# Cargar datos del 2017
df2017 = pd.read_csv("../../datos/crudos/2017.csv", 
                   encoding="latin-1", low_memory=False)

print(f"Fuente 2017: {df2017.shape[0]} rows, {df2017.shape[1]} columns")
# Out:
# Fuente 2017: 155 rows, 12 columns

# %%
df2017.head(2)
# Out:
#    Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0   Norway               1            7.537      7.594445     7.479556
# 1  Denmark               2            7.522      7.581728     7.462272
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707

# %%
# Cargar datos del 2018
df2018 = pd.read_csv("../../datos/crudos/2018.csv", 
                   encoding="latin-1", low_memory=False)

print(f"Fuente 2018: {df2018.shape[0]} rows, {df2018.shape[1]} columns")
# Out:
# Fuente 2018: 156 rows, 9 columns

# %%
df2018.head(2)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340

# %%
# Cargar datos del 2019
df2019 = pd.read_csv("../../datos/crudos/2019.csv", 
                   encoding="latin-1", low_memory=False)

print(f"Fuente 2019: {df2019.shape[0]} rows, {df2019.shape[1]} columns")
# Out:
# Fuente 2019: 156 rows, 9 columns

# %%
df2019.head(2)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410

# %% [markdown]
# ## EDA con ydata_profiling

# %%
#Reporte de fuente 2015
profile1 = ProfileReport(df2015, title="Fuente 2015 - hapiness scores", explorative=True)
profile1.to_file("reporte_2015.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 82.97it/s]

# %%
#Reporte de fuente 2016
profile2 = ProfileReport(df2016, title="Fuente 2016 - hapiness scores", explorative=True)
profile2.to_file("reporte_2016.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 83.33it/s]

# %%
#Reporte de fuente 2017
profile3 = ProfileReport(df2017, title="Fuente 2017 - hapiness scores", explorative=True)
profile3.to_file("reporte_2017.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 66.68it/s]

# %%
#Reporte de fuente 2018
profile4 = ProfileReport(df2018, title="Fuente 2018 - hapiness scores", explorative=True)
profile4.to_file("reporte_2018.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 136.27it/s]

# %%
#Reporte de fuente 2019
profile5 = ProfileReport(df2019, title="Fuente 2019 - hapiness scores", explorative=True)
profile5.to_file("reporte_2019.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 125.02it/s]
